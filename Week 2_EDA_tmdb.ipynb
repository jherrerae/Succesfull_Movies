# %% [markdown]
# # Merge JSON files

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
years=[2000,2001]
files_combined=[]

# %%
for YEAR in years:
    JSON_FILE = f'Data/tmdb_api_results_{YEAR}.json'
    with open(JSON_FILE, 'r') as file:
            files_combined.extend(json.load(file))

# %%
files_combined
# Out:
# [{'imdb_id': 0},
#  {'adult': False,
#   'backdrop_path': '/vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg',
#   'belongs_to_collection': None,
#   'budget': 10000000,
#   'genres': [{'id': 35, 'name': 'Comedy'},
#    {'id': 10402, 'name': 'Music'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 62127,
#   'imdb_id': 'tt0113026',
#   'original_language': 'en',
#   'original_title': 'The Fantasticks',
#   'overview': 'Two rural teens sing and dance their way through a forbidden romance and a dangerous travelling carnival.',
#   'popularity': 2.004,
#   'poster_path': '/hfO64mXz3DgUxkBVU7no2UWRP7x.jpg',
#   'production_companies': [{'id': 60,
#     'logo_path': '/2eqFolQI0NLL7ExZts5MnLLaPwX.png',
#     'name': 'United Artists',
#     'origin_country': 'US'},
#    {'id': 51207,
#     'logo_path': None,
#     'name': 'Sullivan Street Productions',
#     'origin_country': ''},
#    {'id': 51208,
#     'logo_path': None,
#     'name': 'Michael Ritchie Productions',
#     'origin_country': ''},
#    {'id': 51209,
#     'logo_path': None,
#     'name': 'Radmin Company, The',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-09-22',
#   'revenue': 0,
#   'runtime': 86,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Try to remember the first time magic happened',
#   'title': 'The Fantasticks',
#   'video': False,
#   'vote_average': 5.5,
#   'vote_count': 22,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 110977,
#   'imdb_id': 'tt0113092',
#   'original_language': 'en',
#   'original_title': 'For the Cause',
#   'overview': 'Earth is in a state of constant war and two colonies of humans have been sent to a far away world. The colonists create a new civilization but have inherited the worst traits of their forebears and war breaks out leaving the new cities in ruins. It falls to a bunch of teens to bring peace to the colony - but will they?',
#   'popularity': 2.211,
#   'poster_path': '/h9bWO13nWRGZJo4XVPiElXyrRMU.jpg',
#   'production_companies': [{'id': 925,
#     'logo_path': '/dIb9hjXNOkgxu4kBWdIdK8nM4w.png',
#     'name': 'Nu Image',
#     'origin_country': 'US'},
#    {'id': 7405,
#     'logo_path': '/rfnws0uY8rsNAsrLbx3gEIcYXx3.png',
#     'name': 'Dimension Films',
#     'origin_country': 'US'},
#    {'id': 9077,
#     'logo_path': None,
#     'name': 'Martien Holdings A.V.V.',
#     'origin_country': ''},
#    {'id': 12816,
#     'logo_path': None,
#     'name': 'Grand Design Entertainment',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-11-15',
#   'revenue': 0,
#   'runtime': 100,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The ultimate showdown on a forbidden planet.',
#   'title': 'For the Cause',
#   'video': False,
#   'vote_average': 5.1,
#   'vote_count': 8,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'}],
#   'homepage': '',
#   'id': 442869,
#   'imdb_id': 'tt0116391',
#   'original_language': 'hi',
#   'original_title': 'Gang',
#   'overview': 'After falling prey to underworld, four friends jeopardise their personal lives with point of no return.',
#   'popularity': 1.091,
#   'poster_path': '/yB5wRu4uyXXwZA3PEj8cITu0xt3.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'IN', 'name': 'India'}],
#   'release_date': '2000-04-14',
#   'revenue': 0,
#   'runtime': 152,
#   'spoken_languages': [{'english_name': 'Hindi',
#     'iso_639_1': 'hi',
#     'name': 'हिन्दी'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Gang',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg',
#   'belongs_to_collection': None,
#   'budget': 150000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'http://www.wkw-inthemoodforlove.com/',
#   'id': 843,
#   'imdb_id': 'tt0118694',
#   'original_language': 'cn',
#   'original_title': '花樣年華',
#   'overview': 'Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen move into neighboring apartments on the same day. Their encounters are formal and polite—until a discovery about their spouses creates an intimate bond between them.',
#   'popularity': 26.635,
#   'poster_path': '/iYypPT4bhqXfq1b6EnmxvRt6b2Y.jpg',
#   'production_companies': [{'id': 539,
#     'logo_path': None,
#     'name': 'Block 2 Pictures',
#     'origin_country': ''},
#    {'id': 26492,
#     'logo_path': None,
#     'name': 'Jet Tone Films',
#     'origin_country': 'HK'},
#    {'id': 148854,
#     'logo_path': None,
#     'name': 'Orly Films',
#     'origin_country': ''},
#    {'id': 148855,
#     'logo_path': None,
#     'name': 'Paradis Films',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'HK', 'name': 'Hong Kong'}],
#   'release_date': '2000-09-29',
#   'revenue': 12854953,
#   'runtime': 99,
#   'spoken_languages': [{'english_name': 'Cantonese',
#     'iso_639_1': 'cn',
#     'name': '广州话 / 廣州話'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'Feel the heat, keep the feeling burning, let the sensation explode.',
#   'title': 'In the Mood for Love',
#   'video': False,
#   'vote_average': 8.103,
#   'vote_count': 1948,
#   'certification': 'PG'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 49511,
#   'imdb_id': 'tt0118852',
#   'original_language': 'en',
#   'original_title': 'Chinese Coffee',
#   'overview': 'When Harry Levine, an aging, unsuccessful Greenwich Village writer is fired from his job as restaurant doorman, he calls on friend and mentor Jake, ostensibly to collect a long-standing debt. Harry solicits his opinion on his latest manuscript, a work of semi-fiction based on their longtime friendship. Although he initially denies having read it, Jake later attacks it on aesthetic grounds, and deep-seated feelings of betrayal and jealousy surface and lead to a traumatic confrontation.',
#   'popularity': 3.913,
#   'poster_path': '/nZGWnSuf1FIuzyEuMRZHHZWViAp.jpg',
#   'production_companies': [{'id': 1596,
#     'logo_path': None,
#     'name': 'Shooting Gallery',
#     'origin_country': ''},
#    {'id': 67930,
#     'logo_path': None,
#     'name': 'Chal Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-09-02',
#   'revenue': 0,
#   'runtime': 99,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "There's a fine line between friendship and betrayal.",
#   'title': 'Chinese Coffee',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 46,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': '/fClJrAmJQ90zg9gWnfHVYSMiDTv.jpg',
#   'belongs_to_collection': {'id': 141086,
#    'name': 'Heavy Metal Collection',
#    'poster_path': '/tgPpYcsjSo1DK0wublqYItYDwSW.jpg',
#    'backdrop_path': '/iao9hIahX41T1Lxpa5h62J28rQF.jpg'},
#   'budget': 15000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 16225,
#   'imdb_id': 'tt0119273',
#   'original_language': 'en',
#   'original_title': 'Heavy Metal 2000',
#   'overview': "Upon discovery of a shard of what could be the Loc-Nar, a miner named Tyler becomes possessed with an insatiable hunger for power and a thirst for immortality. On his way to the planet of youth, Tyler wipes out most of a space colony and kidnaps a beautiful young woman. His only mistake is that he doesn't kill her sister, Julie, who then sets out on a mission of rescue and revenge.",
#   'popularity': 10.635,
#   'poster_path': '/mzOgKYOXiuwE5DIfagFs34bOb3J.jpg',
#   'production_companies': [{'id': 5,
#     'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#     'name': 'Columbia Pictures',
#     'origin_country': 'US'},
#    {'id': 2216,
#     'logo_path': None,
#     'name': 'Helkon Media',
#     'origin_country': 'DE'},
#    {'id': 15546,
#     'logo_path': None,
#     'name': 'Cine Groupe',
#     'origin_country': ''},
#    {'id': 91006,
#     'logo_path': None,
#     'name': 'Das Werk Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'DE', 'name': 'Germany'}],
#   'release_date': '2000-04-19',
#   'revenue': 0,
#   'runtime': 88,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'not to survive the fight in the external world without inner strength',
#   'title': 'Heavy Metal 2000',
#   'video': False,
#   'vote_average': 6.068,
#   'vote_count': 155,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 51181,
#   'imdb_id': 'tt0119495',
#   'original_language': 'en',
#   'original_title': 'Love 101',
#   'overview': 'Study hard.',
#   'popularity': 0.699,
#   'poster_path': '/42dUuv3lVaJe7wubwJhorWul3HI.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2000-08-24',
#   'revenue': 0,
#   'runtime': 86,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Love 101',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 85920,
#   'imdb_id': 'tt0119806',
#   'original_language': 'en',
#   'original_title': 'Nothing Sacred',
#   'overview': "Three longtime pals live in San Francisco: Darin is married to Natalie, but their family life is too still and Darin is not happy about it, Matt is ladies' magnet but tired of it, trying to get something stable from his relationships, and goofy Kevin doesn't have any success with women at all. Darin starts an affair with his friend's wife Maxine and Matt falls deeply in love with a woman he has seen once.",
#   'popularity': 0.6,
#   'poster_path': '/zunFOl8mNIICL4I9A0gvgOcxVhE.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2000-11-09',
#   'revenue': 0,
#   'runtime': 98,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Nothing Sacred',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/tuerGhZ1lA8wpBjUCEUpeTWDT5B.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}],
#   'homepage': 'http://www.newline.com/properties/stateandmain.html',
#   'id': 21991,
#   'imdb_id': 'tt0120202',
#   'original_language': 'en',
#   'original_title': 'State and Main',
#   'overview': 'A movie crew invades a small town whose residents are all too ready to give up their values for showbiz glitz.',
#   'popularity': 7.331,
#   'poster_path': '/348hvpWeSGdAQlCrGvKbpC0FpQN.jpg',
#   'production_companies': [{'id': 8,
#     'logo_path': '/78ilmDNTpdCfsakrsLqmAUkFTrO.png',
#     'name': 'Fine Line Features',
#     'origin_country': ''},
#    {'id': 21760,
#     'logo_path': None,
#     'name': 'Filmtown Entertainment Group',
#     'origin_country': ''},
#    {'id': 23034,
#     'logo_path': None,
#     'name': 'El Dorado Pictures',
#     'origin_country': ''},
#    {'id': 53672,
#     'logo_path': None,
#     'name': 'Green/Renzi',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2000-08-26',
#   'revenue': 0,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'Italian',
#     'iso_639_1': 'it',
#     'name': 'Italiano'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Big movie. Small town. Huge trouble.',
#   'title': 'State and Main',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 162,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': '/ynXVuylP8upazjz8lrqb1PEMkdR.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 34070,
#   'imdb_id': 'tt0120263',
#   'original_language': 'sv',
#   'original_title': 'Sånger från andra våningen',
#   'overview': 'A film poem inspired by the Peruvian poet César Vallejo. A story about our need for love, our confusion, greatness and smallness and, most of all, our vulnerability. It is a story with many characters, among them a father and his mistress, his youngest son and his girlfriend. It is a film about big lies, abandonment and the eternal longing for companionship and confirmation.',
#   'popularity': 6.716,
#   'poster_path': '/heW06kNneH6nL59h4ZoaODYXFmY.jpg',
#   'production_companies': [{'id': 157,
#     'logo_path': None,
#     'name': 'SVT Drama',
#     'origin_country': ''},
#    {'id': 5402,
#     'logo_path': '/iYQ3d8XgHgmvvuphqIr7amSDqwH.png',
#     'name': 'Easy Film',
#     'origin_country': 'DK'},
#    {'id': 5403,
#     'logo_path': '/fAz2WhTpoMxutBA92JqlfeHEGuz.png',
#     'name': 'Nordisk Film & TV Fond',
#     'origin_country': 'NO'},
#    {'id': 5405,
#     'logo_path': None,
#     'name': 'Roy Andersson Filmproduktion AB',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'SE', 'name': 'Sweden'},
#    {'iso_3166_1': 'DK', 'name': 'Denmark'},
#    {'iso_3166_1': 'NO', 'name': 'Norway'}],
#   'release_date': '2000-10-06',
#   'revenue': 80334,
#   'runtime': 98,
#   'spoken_languages': [{'english_name': 'Russian',
#     'iso_639_1': 'ru',
#     'name': 'Pусский'},
#    {'english_name': 'Swedish', 'iso_639_1': 'sv', 'name': 'svenska'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Songs from the Second Floor',
#   'video': False,
#   'vote_average': 7.242,
#   'vote_count': 215,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': '/knok3mNReKqPTplnnqz7E4dd7mD.jpg',
#   'belongs_to_collection': None,
#   'budget': 120000,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 27, 'name': 'Horror'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 80, 'name': 'Crime'}],
#   'homepage': '',
#   'id': 19085,
#   'imdb_id': 'tt0120467',
#   'original_language': 'en',
#   'original_title': 'Vulgar',
#   'overview': "Vulgar is about a man who is a children's clown but has not been getting much luck lately. He lives in a cheap apartment which he can't even afford. Bums are constantly sleeping in his run down car and crashing on his lawn. He has a nagging mother who lives in a nursing home, and his best friend is a moocher. One day he comes up with the idea to become a bachelor clown.",
#   'popularity': 3.636,
#   'poster_path': '/aLdezroGbHDP0w0jOLwxXjgrgma.jpg',
#   'production_companies': [{'id': 16934,
#     'logo_path': '/7HEUbdTlFQWf4SKidP8S29yFgoW.png',
#     'name': 'View Askew Productions',
#     'origin_country': 'US'},
#    {'id': 102045,
#     'logo_path': None,
#     'name': 'Chango Productions',
#     'origin_country': ''},
#    {'id': 102046,
#     'logo_path': None,
#     'name': 'Shongo Filmworks Ltd.',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2002-04-26',
#   'revenue': 14904,
#   'runtime': 87,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Everyone loves a clown... some more than others.',
#   'title': 'Vulgar',
#   'video': False,
#   'vote_average': 5.4,
#   'vote_count': 42,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': '/6xz9H7IMK3W21SNwAVmE9oW6YjX.jpg',
#   'belongs_to_collection': None,
#   'budget': 6105121,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}],
#   'homepage': '',
#   'id': 54380,
#   'imdb_id': 'tt0120626',
#   'original_language': 'pt',
#   'original_title': 'Capitães de Abril',
#   'overview': 'Story of the 1974 coup that overthrew the right-wing Portuguese dictatorship--which continued the fascist policies of long-time dictator Antonio Salazar--and of two young army captains who were involved in it.',
#   'popularity': 3.018,
#   'poster_path': '/rjWTWWt6nWNg0IqxiY2N5EANRLm.jpg',
#   'production_companies': [{'id': 83,
#     'logo_path': '/9OQ0rm55xtlgX7KcAKMUePJSrQc.png',
#     'name': 'France 2 Cinéma',
#     'origin_country': 'FR'},
#    {'id': 94,
#     'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png',
#     'name': 'ARTE France Cinéma',
#     'origin_country': 'FR'},
#    {'id': 981,
#     'logo_path': '/pkrdO9ykplO4Zc8edikoSX5APUN.png',
#     'name': 'TVE',
#     'origin_country': 'ES'},
#    {'id': 1244,
#     'logo_path': None,
#     'name': 'Alia Films',
#     'origin_country': 'FR'},
#    {'id': 3883,
#     'logo_path': None,
#     'name': 'JBA Production',
#     'origin_country': 'FR'},
#    {'id': 6849,
#     'logo_path': '/AjdOGHRLAhWbP1aAga85A9EOfD2.png',
#     'name': 'SFP',
#     'origin_country': 'FR'},
#    {'id': 8492,
#     'logo_path': '/wYhNCpXIThYDXevad6n90vsMXZ2.png',
#     'name': 'RTP',
#     'origin_country': 'PT'},
#    {'id': 16389, 'logo_path': None, 'name': 'FMB Films', 'origin_country': ''},
#    {'id': 113162,
#     'logo_path': None,
#     'name': 'Mutante Filmes',
#     'origin_country': 'PT'}],
#   'production_countries': [{'iso_3166_1': 'PT', 'name': 'Portugal'},
#    {'iso_3166_1': 'ES', 'name': 'Spain'},
#    {'iso_3166_1': 'IT', 'name': 'Italy'},
#    {'iso_3166_1': 'FR', 'name': 'France'}],
#   'release_date': '2000-04-21',
#   'revenue': 0,
#   'runtime': 123,
#   'spoken_languages': [{'english_name': 'Portuguese',
#     'iso_639_1': 'pt',
#     'name': 'Português'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Captains of April',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 47},
#  {'adult': False,
#   'backdrop_path': '/sPAwM8WxMdXNlqeP4F9DMe9LYoY.jpg',
#   'belongs_to_collection': {'id': 718551,
#    'name': 'Chicken Run Collection',
#    'poster_path': '/rn3ZedQ6AfA60xG2WDe8FRIW29G.jpg',
#    'backdrop_path': '/3ruzhPlPlfnDY4aX7Hx9o5auyJd.jpg'},
#   'budget': 45000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': '',
#   'id': 7443,
#   'imdb_id': 'tt0120630',
#   'original_language': 'en',
#   'original_title': 'Chicken Run',
#   'overview': 'Having been hopelessly repressed and facing eventual certain death at the British chicken farm where they are held, Ginger the chicken along with the help of Rocky the American rooster decide to rebel and lead their fellow chickens in a great escape from the murderous farmers Mr. and Mrs. Tweedy and their farm of doom.',
#   'popularity': 51.497,
#   'poster_path': '/8XgmIsbpVamdhwcNVsYzohFZTtT.jpg',
#   'production_companies': [{'id': 7,
#     'logo_path': '/vru2SssLX3FPhnKZGtYw00pVIS9.png',
#     'name': 'DreamWorks Pictures',
#     'origin_country': 'US'},
#    {'id': 297,
#     'logo_path': '/ykJbf1z5qIreJrHWfnh1ev1alkD.png',
#     'name': 'Aardman Animations',
#     'origin_country': 'GB'},
#    {'id': 521,
#     'logo_path': '/kP7t6RwGz2AvvTkvnI1uteEwHet.png',
#     'name': 'DreamWorks Animation',
#     'origin_country': 'US'},
#    {'id': 7981,
#     'logo_path': '/6Yv1gIAuGkHS5Vis4UjnqHhCPWV.png',
#     'name': 'Pathé',
#     'origin_country': 'FR'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'},
#    {'iso_3166_1': 'FR', 'name': 'France'}],
#   'release_date': '2000-06-21',
#   'revenue': 224834564,
#   'runtime': 84,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "This ain't no chick flick. It's poultry in motion.",
#   'title': 'Chicken Run',
#   'video': False,
#   'vote_average': 6.725,
#   'vote_count': 4101,
#   'certification': 'G'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 272452,
#   'imdb_id': 'tt0120698',
#   'original_language': 'en',
#   'original_title': 'The Highwayman',
#   'overview': 'Road trips have never been this killer! Jason Priestley stars as Breakfast, a psychotic jewelry store thief whose grip on reality is frighteningly precarious. With his accomplice Panda, the duo make off with a carload of cash, a result of a tip-off from beautiful cashier Ziggy. Her reward: to hitch a ride with the out-of-control duo so that she can meet her long-lost father Francis. But Breakfast is on a suicidal quest to even a score with his former boss and has the cops hot on his trail. Rage, murder and revenge are about to collide!',
#   'popularity': 1.181,
#   'poster_path': '/8L5ndBKXg8xKv6z3iZpVHNZbBlv.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'},
#    {'iso_3166_1': 'CA', 'name': 'Canada'}],
#   'release_date': '2000-01-01',
#   'revenue': 0,
#   'runtime': 94,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The Highwayman',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 1,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}],
#   'homepage': '',
#   'id': 146499,
#   'imdb_id': 'tt0120733',
#   'original_language': 'en',
#   'original_title': 'Lion of Oz',
#   'overview': 'Before Dorothy landed on the Wicked Witch of the East with her little farm house, the witch had to contend with another resident of middle America. The Lion, who was once part of the Omaha Circus, comes to Oz with the Wizard and starts on an adventure to stop the witch from obtaining the Flower of Oz. As new friends and strange characters look to him for his courage, Lion could loose exactly what it is that makes him so brave. Based upon the book by Roger S. Baum (Great-Grandson of Oz L. Frank Baum, the original author of the Oz books). Written by Max Vaughn',
#   'popularity': 1.727,
#   'poster_path': '/utXFBWyo4i4LaEZKblOG9viZx5N.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-09-26',
#   'revenue': 0,
#   'runtime': 74,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'A circus lion finds himself in a magical land where he becomes the leader of a journey to stop the Wicked Witch of the East, a task which may lead him to loose a part of himself.',
#   'title': 'Lion of Oz',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 8,
#   'certification': 'NR'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 8000000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 318,
#   'imdb_id': 'tt0120753',
#   'original_language': 'en',
#   'original_title': 'The Million Dollar Hotel',
#   'overview': 'The Million Dollar Hotel starts with a jump from a roof top that clears up a death in a hotel that was burning to the ground where a lot of strange people had been living.',
#   'popularity': 8.389,
#   'poster_path': '/7AjzGYybwfndxnpApKXahQiq2Zy.jpg',
#   'production_companies': [{'id': 1490,
#     'logo_path': None,
#     'name': 'Kintop Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'},
#    {'iso_3166_1': 'DE', 'name': 'Germany'}],
#   'release_date': '2000-02-09',
#   'revenue': 105983,
#   'runtime': 122,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Everyone has something to hide.',
#   'title': 'The Million Dollar Hotel',
#   'video': False,
#   'vote_average': 5.915,
#   'vote_count': 254,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': '/24DZfupDlhXeTchmcOkoGRhP5Vg.jpg',
#   'belongs_to_collection': {'id': 87359,
#    'name': 'Mission: Impossible Collection',
#    'poster_path': '/geEjCGfdmRAA1skBPwojcdvnZ8A.jpg',
#    'backdrop_path': '/jYl0UuJFcmhymv9ZNO14lPLDY1Z.jpg'},
#   'budget': 125000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': '',
#   'id': 955,
#   'imdb_id': 'tt0120755',
#   'original_language': 'en',
#   'original_title': 'Mission: Impossible II',
#   'overview': 'With computer genius Luther Stickell at his side and a beautiful thief on his mind, agent Ethan Hunt races across Australia and Spain to stop a former IMF agent from unleashing a genetically engineered biological weapon called Chimera. This mission, should Hunt choose to accept it, plunges him into the center of an international crisis of terrifying magnitude.',
#   'popularity': 37.18,
#   'poster_path': '/2njB2A85Ni7bRR7vIOrfv6TBPeC.jpg',
#   'production_companies': [{'id': 4,
#     'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png',
#     'name': 'Paramount',
#     'origin_country': 'US'},
#    {'id': 44,
#     'logo_path': None,
#     'name': 'Cruise/Wagner Productions',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-05-24',
#   'revenue': 546388105,
#   'runtime': 123,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Expect the impossible again.',
#   'title': 'Mission: Impossible II',
#   'video': False,
#   'vote_average': 6.107,
#   'vote_count': 5441,
#   'certification': 'PG-13'},
#  {'adult': False,
#   'backdrop_path': '/lAFUFuxy74r4dUw2pmxTtzkfSDE.jpg',
#   'belongs_to_collection': {'id': 748,
#    'name': 'X-Men Collection',
#    'poster_path': '/31rqs6ZxFdi5nWZZaFPIr17q8jt.jpg',
#    'backdrop_path': '/roZFGw3Rg6VOYty9y4r5WvgvXoC.jpg'},
#   'budget': 75000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.20thcenturystudios.com/movies/x-men',
#   'id': 36657,
#   'imdb_id': 'tt0120903',
#   'original_language': 'en',
#   'original_title': 'X-Men',
#   'overview': 'Two mutants, Rogue and Wolverine, come to a private academy for their kind whose resident superhero team, the X-Men, must oppose a terrorist organization with similar powers.',
#   'popularity': 2.556,
#   'poster_path': '/ypiv2HEiNftzrg9ovDCFv16Q6Ti.jpg',
#   'production_companies': [{'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 431,
#     'logo_path': None,
#     'name': "The Donners' Company",
#     'origin_country': 'US'},
#    {'id': 9168,
#     'logo_path': '/hQNXrYIuyLRxMSBuGHk0GX7CCBS.png',
#     'name': 'Bad Hat Harry Productions',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-07-13',
#   'revenue': 296339527,
#   'runtime': 104,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Trust a few. Fear the rest.',
#   'title': 'X-Men',
#   'video': False,
#   'vote_average': 6.985,
#   'vote_count': 9780,
#   'certification': 'PG-13'},
#  {'adult': False,
#   'backdrop_path': '/pniACHS8KDVCldB3BlwL78RIZ7V.jpg',
#   'belongs_to_collection': None,
#   'budget': 75000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': '',
#   'id': 7450,
#   'imdb_id': 'tt0120913',
#   'original_language': 'en',
#   'original_title': 'Titan A.E.',
#   'overview': "A young man finds out that he holds the key to restoring hope and ensuring survival for the human race, while an alien species called the Drej are bent on mankind's destruction.",
#   'popularity': 16.717,
#   'poster_path': '/el2iHk3LTJWfEnwrvcRkvWY501G.jpg',
#   'production_companies': [{'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 11050,
#     'logo_path': None,
#     'name': 'David Kirschner Productions',
#     'origin_country': ''},
#    {'id': 11231,
#     'logo_path': None,
#     'name': 'Fox Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-06-16',
#   'revenue': 36754634,
#   'runtime': 94,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Mandarin', 'iso_639_1': 'zh', 'name': '普通话'}],
#   'status': 'Released',
#   'tagline': 'When Earth Ends, The Adventure Begins.',
#   'title': 'Titan A.E.',
#   'video': False,
#   'vote_average': 6.593,
#   'vote_count': 879,
#   'certification': 'PG'},
#  {'adult': False,
#   'backdrop_path': '/neH7GNmzMs1BDLqHXOnTuB04dNh.jpg',
#   'belongs_to_collection': {'id': 178117,
#    'name': "The Emperor's New Groove Collection",
#    'poster_path': '/gCRRjTXVnLrSQMpWGz1Bgz6Zy5Z.jpg',
#    'backdrop_path': '/hrm42649hDK4zCSEZlRWX1k1qS2.jpg'},
#   'budget': 100000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': '',
#   'id': 11688,
#   'imdb_id': 'tt0120917',
#   'original_language': 'en',
#   'original_title': "The Emperor's New Groove",
#   'overview': "Kuzco is a self-centered emperor who summons Pacha from a village and to tell him that his home will be destroyed to make room for Kuzco's new summer home. Kuzco's advisor, Yzma, tries to poison Kuzco and accidentally turns him into a llama, who accidentally ends up in Pacha's village. Pacha offers to help Kuzco if he doesn't destroy his house, and so they form an unlikely partnership.",
#   'popularity': 91.323,
#   'poster_path': '/wwbgkXQBEKtnyIJapk6gUgWkVw8.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 171656,
#     'logo_path': None,
#     'name': 'Walt Disney Feature Animation',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-12-15',
#   'revenue': 169327687,
#   'runtime': 78,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "It's all about... ME!",
#   'title': "The Emperor's New Groove",
#   'video': False,
#   'vote_average': 7.547,
#   'vote_count': 5583,
#   'certification': 'G'},
#  {'adult': False,
#   'backdrop_path': '/tqEAmypPALBhmwdp9Bo0EcDgKym.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 209084,
#   'imdb_id': 'tt0122161',
#   'original_language': 'en',
#   'original_title': 'Lured Innocence',
#   'overview': 'A reporter sent to cover a murder trial discovers a web of deceit stemming from a torrid affair.',
#   'popularity': 2.185,
#   'poster_path': '/kyg8ZjOf2gerMHZQYZhEiKmHmbp.jpg',
#   'production_companies': [{'id': 70910,
#     'logo_path': None,
#     'name': 'Lured Innocence Productions Inc.',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-02-12',
#   'revenue': 0,
#   'runtime': 97,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Deceptive passion... Malicious seduction.',
#   'title': 'Lured Innocence',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 5,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': '/oNOJoW2XoH3shkQxHtOyacJRBCQ.jpg',
#   'belongs_to_collection': None,
#   'budget': 24000000,
#   'genres': [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 2621,
#   'imdb_id': 'tt0122459',
#   'original_language': 'en',
#   'original_title': 'Return to Me',
#   'overview': "It took a lot of cajoling to get Bob, a recently widowed architect, to go on a blind date at a quirky Irish-Italian eatery. Once there, he's smitten instantly not with his date but with the sharp-witted waitress. Everything seems to be going great until an unbelievable truth is revealed, one that could easily break both of their hearts for good.",
#   'popularity': 11.346,
#   'poster_path': '/89hcHolg5jZcPK0s0a8DW69eCiN.jpg',
#   'production_companies': [{'id': 21,
#     'logo_path': '/aOWKh4gkNrfFZ3Ep7n0ckPhoGb5.png',
#     'name': 'Metro-Goldwyn-Mayer',
#     'origin_country': 'US'},
#    {'id': 65402,
#     'logo_path': None,
#     'name': 'JLT Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-04-07',
#   'revenue': 36609995,
#   'runtime': 115,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'A comedy straight from the heart',
#   'title': 'Return to Me',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 324,
#   'certification': 'PG'},
#  {'adult': False,
#   'backdrop_path': '/2vJe8fmPu5rxlH9lJlcHrj7bs2u.jpg',
#   'belongs_to_collection': None,
#   'budget': 10000000,
#   'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 95136,
#   'imdb_id': 'tt0123003',
#   'original_language': 'en',
#   'original_title': 'Bruno',
#   'overview': 'The story of a unique young boy genius, Bruno, whose expression of his own individuality leads his family and community along an emotional journey.',
#   'popularity': 4.044,
#   'poster_path': '/xs2XKvQkKFB0zm4eLVLcMMRexbJ.jpg',
#   'production_companies': [{'id': 12474,
#     'logo_path': None,
#     'name': 'J&M Entertainment',
#     'origin_country': ''},
#    {'id': 12475,
#     'logo_path': None,
#     'name': 'Original Voices Inc.',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-04-16',
#   'revenue': 0,
#   'runtime': 108,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The comedy that is long on originality and short on pants.',
#   'title': 'Bruno',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 24,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}],
#   'homepage': '',
#   'id': 248740,
#   'imdb_id': 'tt0123055',
#   'original_language': 'en',
#   'original_title': "The Elf Who Didn't Believe",
#   'overview': "Elmer, an elf child, steals Santa's sleigh and goes out to the real world, pretending to be a real boy.",
#   'popularity': 0.662,
#   'poster_path': '/urmN4BHYLLGWP89U3SFfEbhG6x2.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '1997-01-02',
#   'revenue': 0,
#   'runtime': 90,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': "The Elf Who Didn't Believe",
#   'video': False,
#   'vote_average': 4.0,
#   'vote_count': 1,
#   'certification': 'G'},
#  {'adult': False,
#   'backdrop_path': '/wW2binZ7EVPGy5gEsIoMKICckcQ.jpg',
#   'belongs_to_collection': None,
#   'budget': 8500000,
#   'genres': [{'id': 9648, 'name': 'Mystery'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 37722,
#   'imdb_id': 'tt0127349',
#   'original_language': 'en',
#   'original_title': 'Waking the Dead',
#   'overview': 'A congressional candidate questions his sanity after seeing the love of his life, presumed dead, suddenly emerge.',
#   'popularity': 8.643,
#   'poster_path': '/wC4MSw7MYYDIhkcgw1lZui0kzur.jpg',
#   'production_companies': [{'id': 37,
#     'logo_path': '/24D25UH5SyteudhPXW6Oy0Qfj1q.png',
#     'name': 'Gramercy Pictures',
#     'origin_country': 'US'},
#    {'id': 802,
#     'logo_path': None,
#     'name': 'Egg Pictures',
#     'origin_country': ''},
#    {'id': 1382,
#     'logo_path': '/sOg7LGESPH5vCTOIdbMhLuypoLL.png',
#     'name': 'PolyGram Filmed Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2000-03-24',
#   'revenue': 327418,
#   'runtime': 105,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "Sometimes love has a life of it's own.",
#   'title': 'Waking the Dead',
#   'video': False,
#   'vote_average': 6.243,
#   'vote_count': 70,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 27, 'name': 'Horror'}],
#   'homepage': '',
#   'id': 445773,
#   'imdb_id': 'tt0128158',
#   'original_language': 'en',
#   'original_title': 'Deadfall',
#   'overview': 'A dark supernatural force is unleashed, spoiling a weekend trip.',
#   'popularity': 0.931,
#   'poster_path': '/jlqgqF7ftahZV1XZXAipXrAnjbt.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-01-01',
#   'revenue': 0,
#   'runtime': 86,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Chaos has awakened.',
#   'title': 'Deadfall',
#   'video': False,
#   'vote_average': 4.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/laeEtakR2pLKu3CeRwB2lU5Y53X.jpg',
#   'belongs_to_collection': None,
#   'budget': 127500000,
#   'genres': [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}],
#   'homepage': '',
#   'id': 10567,
#   'imdb_id': 'tt0130623',
#   'original_language': 'en',
#   'original_title': 'Dinosaur',
#   'overview': 'An orphaned dinosaur raised by lemurs joins an arduous trek to a sancturary after a meteorite shower destroys his family home.',
#   'popularity': 90.892,
#   'poster_path': '/rSje3FS7ycJSglowlngjsvDt7vO.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 171656,
#     'logo_path': None,
#     'name': 'Walt Disney Feature Animation',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-05-19',
#   'revenue': 354248063,
#   'runtime': 82,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'You have never seen anything like this.',
#   'title': 'Dinosaur',
#   'video': False,
#   'vote_average': 6.481,
#   'vote_count': 2070,
#   'certification': 'PG'},
#  {'adult': False,
#   'backdrop_path': '/9K1y8HCokYpuU92jKauiFwu0y7P.jpg',
#   'belongs_to_collection': None,
#   'budget': 76000000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': '',
#   'id': 17711,
#   'imdb_id': 'tt0131704',
#   'original_language': 'en',
#   'original_title': 'The Adventures of Rocky & Bullwinkle',
#   'overview': 'Rocky and Bullwinkle have been living off the finances made from the reruns of their cartoon show. Boris and Natasha somehow manage to crossover into reality and team up with Fearless Leader, an evil criminal turned media mogul with some evil plans up his sleeve. Rocky and Bullwinkle must stop the three of them before they wreak havoc.',
#   'popularity': 9.535,
#   'poster_path': '/xCFSsftt2rglC81I6QLWcZSTCBM.jpg',
#   'production_companies': [{'id': 33,
#     'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'},
#    {'id': 594,
#     'logo_path': None,
#     'name': 'Capella International',
#     'origin_country': ''},
#    {'id': 11391,
#     'logo_path': '/t6m0uRTzaFHCsvEpikENE0PWJGb.png',
#     'name': 'Tribeca Productions',
#     'origin_country': 'US'},
#    {'id': 22182, 'logo_path': None, 'name': 'KC Medien', 'origin_country': ''},
#    {'id': 32809,
#     'logo_path': None,
#     'name': 'Wildbrain Entertainment',
#     'origin_country': 'US'},
#    {'id': 67002,
#     'logo_path': None,
#     'name': 'Jay Ward Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2000-06-30',
#   'revenue': 35134820,
#   'runtime': 88,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "This summer it's not the same old bull.",
#   'title': 'The Adventures of Rocky & Bullwinkle',
#   'video': False,
#   'vote_average': 4.072,
#   'vote_count': 306,
#   'certification': 'PG'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}],
#   'homepage': '',
#   'id': 44574,
#   'imdb_id': 'tt0132885',
#   'original_language': 'en',
#   'original_title': 'Blackmale',
#   'overview': 'Two desperate con men attempt to blackmail a psychotic doctor who may just be a serial killer.',
#   'popularity': 1.111,
#   'poster_path': '/4Z6xnqx1lSrikXRklsOWi1R7rVd.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2000-05-11',
#   'revenue': 0,
#   'runtime': 90,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': "Money, love and guns. It's payback time",
#   'title': 'Blackmale',
#   'video': False,
#   'vote_average': 4.7,
#   'vote_count': 5},
#  {'adult': False,
#   'backdrop_path': '/s6cgAveWCam2hYgdPhD3WbrjSBt.jpg',
#   'belongs_to_collection': {'id': 9436,
#    'name': 'The Crow Collection',
#    'poster_path': '/kfU8OZptlBfR5DL9LNGL301Zmlz.jpg',
#    'backdrop_path': '/xxJs7xqY0vMuNlznQboBzq8RlZm.jpg'},
#   'budget': 10000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 53, 'name': 'Thriller'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 9648, 'name': 'Mystery'}],
#   'homepage': 'https://www.miramax.com/movie/crow-iii-salvation/',
#   'id': 9456,
#   'imdb_id': 'tt0132910',
#   'original_language': 'en',
#   'original_title': 'The Crow: Salvation',
#   'overview': 'Alex Corvis returns to the world of the living to avenge the murder of his girlfriend, who he was wrongly accused of killing. But first he must uncover the truth about who really killed her.',
#   'popularity': 12.874,
#   'poster_path': '/wA8nRfRyv17CCIn0xFsH9aZe7jw.jpg',
#   'production_companies': [{'id': 4030,
#     'logo_path': None,
#     'name': 'Jeff Most Productions',
#     'origin_country': ''},
#    {'id': 6455,
#     'logo_path': None,
#     'name': 'Pressman Film',
#     'origin_country': 'US'},
#    {'id': 65403,
#     'logo_path': None,
#     'name': 'IMF Internationale Medien und Film GmbH & Co. Produktions KG',
#     'origin_country': ''},
#    {'id': 138907,
#     'logo_path': None,
#     'name': 'Image Comics',
#     'origin_country': ''},
#    {'id': 140434,
#     'logo_path': None,
#     'name': 'Fallen Bird Productions Inc.',
#     'origin_country': ''},
#    {'id': 140435,
#     'logo_path': None,
#     'name': 'Pacifica Film Distribution',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2000-10-31',
#   'revenue': 0,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'For Vengeance, For Justice, For Love.',
#   'title': 'The Crow: Salvation',
#   'video': False,
#   'vote_average': 5.388,
#   'vote_count': 251,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 53, 'name': 'Thriller'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 278828,
#   'imdb_id': 'tt0133752',
#   'original_language': 'en',
#   'original_title': 'Fallen Arches',
#   'overview': 'Transplanted from New York, Duke and his brother Frankie Romano live in a rundown LA apartment with their alcoholic mother (Karen Black).',
#   'popularity': 0.6,
#   'poster_path': '/sNGqJObApRoXV1p4s6We601Avjl.jpg',
#   'production_companies': [{'id': 59172,
#     'logo_path': None,
#     'name': 'Saraghina Film Company',
#     'origin_country': ''}],
#   'production_countries': [],
#   'release_date': '2000-01-15',
#   'revenue': 0,
#   'runtime': 100,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Two brothers, one gangster, and the most heinous of crimes...',
#   'title': 'Fallen Arches',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': '/yZK4T7ZDQcQr5omvSnJnR9IzBVa.jpg',
#   'belongs_to_collection': {'id': 2602,
#    'name': 'Scream Collection',
#    'poster_path': '/bTumOqx9VSsj6rybzKn6jD83Pg1.jpg',
#    'backdrop_path': '/dZqsivuEhuHMYgLiMjtMXLImRzE.jpg'},
#   'budget': 40000000,
#   'genres': [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}],
#   'homepage': '',
#   'id': 4234,
#   'imdb_id': 'tt0134084',
#   'original_language': 'en',
#   'original_title': 'Scream 3',
#   'overview': 'As bodies begin dropping around the set of ‘Stab 3’ — a movie sequel based on the gruesome Woodsboro killings — Sidney, Gale and Dewey are once again drawn into a game of horror movie mayhem.',
#   'popularity': 35.296,
#   'poster_path': '/qpH8ToZVlFD1bakL04LkEKodyDI.jpg',
#   'production_companies': [{'id': 85,
#     'logo_path': None,
#     'name': 'Konrad Pictures',
#     'origin_country': ''},
#    {'id': 1600,
#     'logo_path': None,
#     'name': 'Craven-Maddalena Films',
#     'origin_country': ''},
#    {'id': 7405,
#     'logo_path': '/rfnws0uY8rsNAsrLbx3gEIcYXx3.png',
#     'name': 'Dimension Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2000-02-03',
#   'revenue': 161834276,
#   'runtime': 116,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Someone has taken their love of trilogies one step too far.',
#   'title': 'Scream 3',
#   'video': False,
#   'vote_average': 5.942,
#   'vote_count': 2630,
#   'certification': 'R'},
#  {'adult': False,
#   'backdrop_path': '/dDJuLVV5K1XYim69Ab8wy9luXu4.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10402, 'name': 'Music'}],
#   'homepage': '',
#   'id': 18074,
#   'imdb_id': 'tt0134630',
#   'original_language': 'en',
#   'original_title': 'Duets',
#   'overview': 'Duets is a road-trip comedy which revolves around the little known world of karaoke and the whimsical characters who inhabit it. All roads lead to Omaha, site of a national karaoke competition where this motley group of singers and stars come together for a blow-out sing-off.',
#   'popularity': 5.26,
# ...
#   'popularity': 0.613,
#   'poster_path': None,
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2001-07-13',
#   'revenue': 0,
#   'runtime': 80,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Waiting',
#   'video': False,
#   'vote_average': 4.8,
#   'vote_count': 6,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'name': 'War'}],
#   'homepage': '',
#   'id': 328362,
#   'imdb_id': 'tt0270104',
#   'original_language': 'sr',
#   'original_title': 'Zemlja istine, ljubavi i slobode',
#   'overview': 'In 1999, during the NATO bombing in Serbia, a young television editor (Boris Milivojevic) in an underground shelter - turned mental institution is having a psychiatric exploration through which he reflects his story...',
#   'popularity': 0.681,
#   'poster_path': None,
#   'production_companies': [{'id': 75663,
#     'logo_path': None,
#     'name': 'Montage',
#     'origin_country': ''},
#    {'id': 93417,
#     'logo_path': None,
#     'name': "Sean Aloysius O'Fearna & Sons",
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'YU', 'name': 'Yugoslavia'}],
#   'release_date': '2000-11-11',
#   'revenue': 0,
#   'runtime': 72,
#   'spoken_languages': [{'english_name': 'Serbian',
#     'iso_639_1': 'sr',
#     'name': 'Srpski'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Land of Truth, Love & Freedom',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/TRBbFTwlwKxi0OQOyuIVltub0e.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [],
#   'homepage': '',
#   'id': 400503,
#   'imdb_id': 'tt0270348',
#   'original_language': 'fa',
#   'original_title': 'اعتراض',
#   'overview': "When Amir learns that the woman who is to marry his younger brother Reza is having an affair with another man, he murders her to restore his family's good name. Considering the killing to be a matter of honor, Amir stoically goes to prison for 12 years where his fellow inmates regard him as a hero. But when he is released, he discovers that the Iran he knew has changed.",
#   'popularity': 0.6,
#   'poster_path': '/8vmLlZlIlD3tvux5pRYmjbNvUoQ.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'IR', 'name': 'Iran'}],
#   'release_date': '2000-01-01',
#   'revenue': 0,
#   'runtime': 100,
#   'spoken_languages': [{'english_name': 'Persian',
#     'iso_639_1': 'fa',
#     'name': 'فارسی'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Protest',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'}],
#   'homepage': '',
#   'id': 856053,
#   'imdb_id': 'tt0270397',
#   'original_language': 'en',
#   'original_title': "Hlou w'Morr",
#   'overview': "Barely relieved from a serious depression and against the advice of his psychiatrist, Slah, theater director, mentally weakened by his career, announces to his wife Amel, a rich woman who finances his projects, his decision to mount the famous play Essoud (The Dam) of Mahmoud Messadi renowned for its complexity. But the same evening, driving his car, Slah overthrows a young woman named Aisha. At first distraught, he then experiences a strange fascination for this beautiful young girl contrarian who becomes his friend and his muse. Amel, her husband's moral, emotional and financial support, convinced the director of the theater to program Le Barrage. Although suffering in silence of the presence of Aisha, Amel decides for love for her husband to invite the young woman near them, in the field of her parents, in an oasis of the south of Tunisia. A strange three-way household is formed when doubts and suspicions, desires and temptations, love and complexities are revealed.",
#   'popularity': 0.621,
#   'poster_path': '/MtlLdx9gJueppFJBlOO8oFY8eu.jpg',
#   'production_companies': [{'id': 27122,
#     'logo_path': None,
#     'name': 'Les Films Sur La Place',
#     'origin_country': ''},
#    {'id': 158267,
#     'logo_path': None,
#     'name': 'Imago Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'},
#    {'iso_3166_1': 'TN', 'name': 'Tunisia'}],
#   'release_date': '2000-10-23',
#   'revenue': 0,
#   'runtime': 91,
#   'spoken_languages': [{'english_name': 'Arabic',
#     'iso_639_1': 'ar',
#     'name': 'العربية'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Sweet And Bitter',
#   'video': False,
#   'vote_average': 9.5,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': '',
#   'id': 180088,
#   'imdb_id': 'tt0270500',
#   'original_language': 'he',
#   'original_title': 'Mashehu Totali',
#   'overview': "Three friends concoct the ultimate love drug, TLV, and fall in love with the same woman, Renana. Years later, Renana's ex-lovers team up to rescue her from an Indian prison.",
#   'popularity': 0.6,
#   'poster_path': '/a9YAsSuq7nKF58BcnThurAs6FFn.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'IL', 'name': 'Israel'}],
#   'release_date': '2000-06-06',
#   'revenue': 0,
#   'runtime': 83,
#   'spoken_languages': [{'english_name': 'Hebrew',
#     'iso_639_1': 'he',
#     'name': 'עִבְרִית'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Total Love',
#   'video': False,
#   'vote_average': 8.0,
#   'vote_count': 2,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': '/xnOUkH3RcAKDajBIXLuntiPkkO8.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 80, 'name': 'Crime'}],
#   'homepage': '',
#   'id': 34729,
#   'imdb_id': 'tt0270560',
#   'original_language': 'en',
#   'original_title': 'Our Lips Are Sealed',
#   'overview': "Mary-Kate and Ashley star in this Down Under adventure filled with nonstop Aussie intrigue, laughs and romance. After running afoul of a notorious gangster, Mary-Kate and Ashley take refuge in the FBI Witness Protection Program. Unfortunately, the girls are uncontrollable blabbermouths and they blow their cover in town after town until there's only one hiding place left - Australia.",
#   'popularity': 8.611,
#   'poster_path': '/40gZ2WhqpZVv8woW0fCH8bMFzx8.jpg',
#   'production_companies': [{'id': 6130,
#     'logo_path': None,
#     'name': 'Dualstar Productions',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'AU', 'name': 'Australia'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2000-05-18',
#   'revenue': 0,
#   'runtime': 89,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Our Lips Are Sealed',
#   'video': False,
#   'vote_average': 6.006,
#   'vote_count': 234,
#   'certification': 'G'},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [],
#   'homepage': '',
#   'id': 501710,
#   'imdb_id': 'tt0270845',
#   'original_language': 'en',
#   'original_title': 'Babs',
#   'overview': 'Babs, mother of 35, falls in love with the nightclub owner Juan Carlos. However their luck runs out when Juan becomes a suspect in a murder case. As if that where not enough, Babs gets kidnapped.',
#   'popularity': 0.6,
#   'poster_path': None,
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2000-12-07',
#   'revenue': 0,
#   'runtime': 90,
#   'spoken_languages': [],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Babs',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/wwtFJCAGlzEMsvnCc7d5M9EKqtd.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 18, 'name': 'Drama'}],
#   'homepage': 'http://bingz.info',
#   'id': 491916,
#   'imdb_id': 'tt0270880',
#   'original_language': 'hi',
#   'original_title': 'Champion',
#   'overview': 'The film CHAMPION is a tale about a man who has a quest, a dream to be the best of the best. The film centres on four main characters, namely Rajveer Singh (Sunny Deol), a simpleton from a village in Punjab, whose sole dream in life is to become a super-cop and wipe off all crime. After, training, he gets his first posting at Mumbai for a special assignment. Bubbling with enthusiasm, an arrival, he is shocked to find that his job is to protect a nine-year-old boy, Abbas Khan (Abhishek Sharma). A bodyguard, after all the rigorous training to eliminate hardcore criminals! Abbas is the sole heir to millions of riches left to him by his parents, who have expired in a drastic plane crash.',
#   'popularity': 2.761,
#   'poster_path': '/s3vmKFqSrXBLlsU7bsn6kEPI6jD.jpg',
#   'production_companies': [{'id': 160726,
#     'logo_path': None,
#     'name': 'Shree Shiv Bhakti Films',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'IN', 'name': 'India'}],
#   'release_date': '2000-12-22',
#   'revenue': 0,
#   'runtime': 160,
#   'spoken_languages': [{'english_name': 'Hindi',
#     'iso_639_1': 'hi',
#     'name': 'हिन्दी'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Champion',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/wGn7q7UCYI6vb6Wez21u0boLHvi.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': '',
#   'id': 81760,
#   'imdb_id': 'tt0270919',
#   'original_language': 'ko',
#   'original_title': '동감',
#   'overview': 'In this endearing supernatural love story spanning two decades, a university student finds himself communicating with a female classmate from the same school through an antique ham radio.',
#   'popularity': 3.734,
#   'poster_path': '/pHgdlgUqfw8Jh6Gh0m9bzsdISUz.jpg',
#   'production_companies': [{'id': 3660,
#     'logo_path': None,
#     'name': 'Hanmac Films',
#     'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#   'release_date': '2000-05-27',
#   'revenue': 0,
#   'runtime': 112,
#   'spoken_languages': [{'english_name': 'Korean',
#     'iso_639_1': 'ko',
#     'name': '한국어/조선말'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Ditto',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 32},
#  {'adult': False,
#   'backdrop_path': '/nvGVPdCIBXXXD6PHhORlhzt5vaL.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': '',
#   'id': 16990,
#   'imdb_id': 'tt0270933',
#   'original_language': 'ja',
#   'original_title': 'エスカフローネ',
#   'overview': "Gaea is a mythical realm ruled by sword and sorcery and immersed in blood and violence. Thrust into a conflict she doesn't quite understand, Hitomi Kanzaki helps aid the young Prince Van as they embark upon a journey to fight the Black Dragon Clan. The battle over a legendary suit of dragon armor, Escaflowne, has begun.",
#   'popularity': 16.697,
#   'poster_path': '/2OA4sQo6PLXAKMvXVd4QlX1eN0l.jpg',
#   'production_companies': [{'id': 528,
#     'logo_path': '/fO3Aof3lXQclYpBByYC8aneTXwA.png',
#     'name': 'Bandai Visual',
#     'origin_country': 'JP'},
#    {'id': 3153,
#     'logo_path': '/yKZ9UarLSu9Y4Gpw33nKRQOPM7z.png',
#     'name': 'SUNRISE',
#     'origin_country': 'JP'}],
#   'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}],
#   'release_date': '2000-06-24',
#   'revenue': 0,
#   'runtime': 98,
#   'spoken_languages': [{'english_name': 'Japanese',
#     'iso_639_1': 'ja',
#     'name': '日本語'}],
#   'status': 'Released',
#   'tagline': 'One will wake it. One will destroy it.',
#   'title': 'Escaflowne: The Movie',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 104,
#   'certification': 'PG-13'},
#  {'adult': False,
#   'backdrop_path': '/jjC46JlFhaTX8kGB2DXbpOxZf8n.jpg',
#   'belongs_to_collection': {'id': 76291,
#    'name': 'Simon Brenner Collection',
#    'poster_path': '/gd1AXBaLsl3F0zBQh9XcBl8kr2E.jpg',
#    'backdrop_path': '/aS4ZAsxx4wa4N1gWpuBUgmKE0S5.jpg'},
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}],
#   'homepage': '',
#   'id': 10469,
#   'imdb_id': 'tt0271029',
#   'original_language': 'de',
#   'original_title': 'Komm, süßer Tod',
#   'overview': 'Former detective Brenner has become an ambulance driver and finds himself, much to his dismay, caught up in a war between two rival first aid organizations.',
#   'popularity': 2.683,
#   'poster_path': '/tweuX8lgvrvZkUIereyO62qWj88.jpg',
#   'production_companies': [{'id': 608,
#     'logo_path': '/dD2Do4GHXAql5c4LjXCbEOvxbFg.png',
#     'name': 'Dor Film Production Company',
#     'origin_country': 'AT'}],
#   'production_countries': [{'iso_3166_1': 'AT', 'name': 'Austria'}],
#   'release_date': '2000-12-22',
#   'revenue': 0,
#   'runtime': 107,
#   'spoken_languages': [{'english_name': 'German',
#     'iso_639_1': 'de',
#     'name': 'Deutsch'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Come, Sweet Death',
#   'video': False,
#   'vote_average': 7.4,
#   'vote_count': 45},
#  {'adult': False,
#   'backdrop_path': None,
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [],
#   'homepage': '',
#   'id': 419019,
#   'imdb_id': 'tt0271193',
#   'original_language': 'en',
#   'original_title': 'Sleepwalk',
#   'overview': 'At loose ends drifter stumbles upon a struggling painter as he searches for answers under the stars and rooftops of New York.',
#   'popularity': 0.6,
#   'poster_path': '/vwC8Y69yS2dx5PUWW2xhtZ9ytgW.jpg',
#   'production_companies': [],
#   'production_countries': [],
#   'release_date': '2000-03-10',
#   'revenue': 0,
#   'runtime': 98,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Sleepwalk',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0,
#   'certification': ''},
#  {'adult': False,
#   'backdrop_path': '/xs6awEGjnH3e36YSAromfYu3PBQ.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 35, 'name': 'Comedy'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': '',
#   'id': 40096,
#   'imdb_id': 'tt0271383',
#   'original_language': 'pt',
#   'original_title': 'O Auto da Compadecida',
#   'overview': 'The lively Jack the Cricket and the sly Chicó are poor guys living in the hinterland who cheat a bunch of people in a small in Northeastern Brazil. When they die, they have to be judged by Christ, the Devil and the Virgin Mary before they are admitted to paradise.',
#   'popularity': 6.965,
#   'poster_path': '/m8eFedsS7vQCZCS8WGp5n1bVD0q.jpg',
#   'production_companies': [{'id': 11446,
#     'logo_path': None,
#     'name': 'Lereby Productions',
#     'origin_country': ''},
#    {'id': 13969,
#     'logo_path': '/vYbpU7yDkLvx4ehvOxuU5BTsFKi.png',
#     'name': 'Globo Filmes',
#     'origin_country': 'BR'}],
#   'production_countries': [{'iso_3166_1': 'BR', 'name': 'Brazil'}],
#   'release_date': '2000-09-15',
#   'revenue': 4903192,
#   'runtime': 104,
#   'spoken_languages': [{'english_name': 'Portuguese',
#     'iso_639_1': 'pt',
#     'name': 'Português'}],
#   'status': 'Released',
#   'tagline': 'Lying with Faith is Not Always a Sin.',
#   'title': "A Dog's Will",
#   'video': False,
#   'vote_average': 8.434,
#   'vote_count': 911},
#  ...]

# %%
len(files_combined)
# Out:
# 2492

# %%
df=pd.DataFrame(files_combined)
df.to_csv("Data/tmdb_results_combined.csv.gz", compression="gzip", index=False)

# %%
df.shape
# Out:
# (2492, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2492 entries, 0 to 2491
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2492 non-null   object
#  1   adult                  2490 non-null   object
#  2   backdrop_path          1290 non-null   object
#  3   belongs_to_collection  197 non-null    object
#  4   budget                 2490 non-null   float64
#  5   genres                 2490 non-null   object
#  6   homepage               2490 non-null   object
#  7   id                     2490 non-null   float64
#  8   original_language      2490 non-null   object
#  9   original_title         2490 non-null   object
#  10  overview               2490 non-null   object
#  11  popularity             2490 non-null   float64
#  12  poster_path            2195 non-null   object
#  13  production_companies   2490 non-null   object
#  14  production_countries   2490 non-null   object
#  15  release_date           2490 non-null   object
#  16  revenue                2490 non-null   float64
#  17  runtime                2490 non-null   float64
#  18  spoken_languages       2490 non-null   object
#  19  status                 2490 non-null   object
#  20  tagline                2490 non-null   object
#  21  title                  2490 non-null   object
#  22  video                  2490 non-null   object
#  23  vote_average           2490 non-null   float64
#  24  vote_count             2490 non-null   float64
#  25  certification          1649 non-null   object
# dtypes: float64(7), object(19)
# memory usage: 506.3+ KB

# %%
filter_revenue=df['revenue']>0
filter_budget=df['budget']>0
df_filtered=df[filter_revenue|filter_budget]

# %%
df_filtered.shape
# Out:
# (619, 26)

# %% [markdown]
# # EDA

# %%
sns.countplot(data=df_filtered,x='certification');

#Movies per certification category

# %%
sns.barplot(data=df_filtered,x='certification',y='revenue',ci=None);

#Average Revenue per Certification

# %%
sns.barplot(data=df_filtered,x='certification',y='budget',ci=None);

#Average Budget per Certification

# %%
df_filtered.groupby('certification',dropna=False)['revenue','budget'].mean()
# Out:
# C:\Users\JoseH\AppData\Local\Temp\ipykernel_6528\763420654.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_filtered.groupby('certification',dropna=False)['revenue','budget'].mean()
#                     revenue        budget
# certification
#                1.114918e+07  5.830014e+06
# G              1.237085e+08  4.085714e+07
# NR             8.887619e+06  6.300006e+06
# PG             1.123378e+08  4.497857e+07
# PG-13          9.970084e+07  4.348391e+07
# R              3.334614e+07  2.013149e+07
# NaN            2.951131e+06  2.002770e+06
